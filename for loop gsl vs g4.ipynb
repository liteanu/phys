// %%
#include <iostream>
#include "G4LegendrePolynomial.hh"
#include <random>
#include <cstdlib>
#include "gsl/gsl_sf_legendre.h"
#include <stdio.h> 
#include <stdlib.h> 
#include <chrono>

{
    G4LegendrePolynomial lp; 
    gsl_sf_legendre_t norm = GSL_SF_LEGENDRE_NONE;
    std::random_device rd;
    std::mt19937 mt(rd());
    std::uniform_real_distribution<double> xdist(-1, 1);
    
    {
       for (int l=0; l < 3; ++l){
          std::vector<double> result_array(gsl_sf_legendre_array_n(l), 0);
           for (int i=0; i < 3; ++i){
                std::cout << "Value of l : " << l << std::endl ;
                std::cout << "value of i: " <<  i  << std::endl ;
                double x = xdist(mt);
                auto started_gsl = std::chrono::high_resolution_clock::now();
                gsl_sf_legendre_array_e(norm, l, x, -1, &(result_array[0]));
                auto done_gsl = std::chrono::high_resolution_clock::now(); 
                std::cout << "value of x: " << x << std::endl ;
                   for (int m = 0; m <= l; ++m){
                       std::cout << "Value of m: " << m << std::endl ;
                       //tg4 start
                       auto started_g4 = std::chrono::high_resolution_clock::now();
                       double alpg4 = lp.EvalAssocLegendrePoly(l, m, x); 
                       auto done_g4 = std::chrono::high_resolution_clock::now(); 
                       std::cout << "from alp g4:" << lp.EvalAssocLegendrePoly(l, m, x) << std::endl;
                       std::cout << "time for g4:" << std::chrono::duration_cast<std::chrono::nanoseconds>(done_g4-started_g4).count() << " nanoseconds"<< std::endl;
                       double gsl = result_array[gsl_sf_legendre_array_index(l, m)] ;
                       std::cout << "from gsl:" << result_array[gsl_sf_legendre_array_index(l, m)] << std::endl;
                       std::cout << "time for gsl:" << std::chrono::duration_cast<std::chrono::nanoseconds>(done_gsl-started_gsl).count() << " nanoseconds"<< std::endl;
                       
                      
               }
           }
       }
    }
}
// Out:
// Value of l : 0
// value of i: 0
// value of x: -0.365771
// Value of m: 0
// from alp g4:1
// time for g4:84033 nanoseconds
// from gsl:1
// time for gsl:4924 nanoseconds
// Value of l : 0
// value of i: 1
// value of x: -0.160821
// Value of m: 0
// from alp g4:1
// time for g4:869 nanoseconds
// from gsl:1
// time for gsl:608 nanoseconds
// Value of l : 0
// value of i: 2
// value of x: -0.713587
// Value of m: 0
// from alp g4:1
// time for g4:579 nanoseconds
// from gsl:1
// time for gsl:651 nanoseconds
// Value of l : 1
// value of i: 0
// value of x: 0.276972
// Value of m: 0
// from alp g4:0.276972
// time for g4:559 nanoseconds
// from gsl:0.276972
// time for gsl:599 nanoseconds
// Value of m: 1
// from alp g4:-0.960878
// time for g4:703 nanoseconds
// from gsl:-0.960878
// time for gsl:599 nanoseconds
// Value of l : 1
// value of i: 1
// value of x: 0.691914
// Value of m: 0
// from alp g4:0.691914
// time for g4:773 nanoseconds
// from gsl:0.691914
// time for gsl:582 nanoseconds
// Value of m: 1
// from alp g4:-0.72198
// time for g4:816 nanoseconds
// from gsl:-0.72198
// time for gsl:582 nanoseconds
// Value of l : 1
// value of i: 2
// value of x: 0.62698
// Value of m: 0
// from alp g4:0.62698
// time for g4:514 nanoseconds
// from gsl:0.62698
// time for gsl:511 nanoseconds
// Value of m: 1
// from alp g4:-0.779036
// time for g4:480 nanoseconds
// from gsl:-0.779036
// time for gsl:511 nanoseconds
// Value of l : 2
// value of i: 0
// value of x: 0.747118
// Value of m: 0
// from alp g4:0.337279
// time for g4:523 nanoseconds
// from gsl:0.337279
// time for gsl:759 nanoseconds
// Value of m: 1
// from alp g4:-1.48981
// time for g4:560 nanoseconds
// from gsl:-1.48981
// time for gsl:759 nanoseconds
// Value of m: 2
// from alp g4:1.32544
// time for g4:610 nanoseconds
// from gsl:1.32544
// time for gsl:759 nanoseconds
// Value of l : 2
// value of i: 1
// value of x: 0.885183
// Value of m: 0
// from alp g4:0.675324
// time for g4:388 nanoseconds
// from gsl:0.675324
// time for gsl:550 nanoseconds
// Value of m: 1
// from alp g4:-1.23547
// time for g4:1138 nanoseconds
// from gsl:-1.23547
// time for gsl:550 nanoseconds
// Value of m: 2
// from alp g4:0.649352
// time for g4:342 nanoseconds
// from gsl:0.649352
// time for gsl:550 nanoseconds
// Value of l : 2
// value of i: 2
// value of x: 0.254514
// Value of m: 0
// from alp g4:-0.402834
// time for g4:372 nanoseconds
// from gsl:-0.402834
// time for gsl:553 nanoseconds
// Value of m: 1
// from alp g4:-0.738398
// time for g4:336 nanoseconds
// from gsl:-0.738398
// time for gsl:553 nanoseconds
// Value of m: 2
// from alp g4:2.80567
// time for g4:317 nanoseconds
// from gsl:2.80567
// time for gsl:553 nanoseconds
