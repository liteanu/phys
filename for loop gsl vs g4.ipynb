// %%
#include <iostream>
#include "G4LegendrePolynomial.hh"
#include <random>
#include <cstdlib>
#include "gsl/gsl_sf_legendre.h"
#include <stdio.h> 
#include <stdlib.h> 
#include <chrono>

{
    G4LegendrePolynomial lp; 
    gsl_sf_legendre_t norm = GSL_SF_LEGENDRE_NONE;
    std::random_device rd;
    std::mt19937 mt(rd());
    std::uniform_real_distribution<double> xdist(-1, 1);
    
    {
       for (int l=0; l < 3; ++l){
          std::vector<double> result_array(gsl_sf_legendre_array_n(l), 0);
           for (int i=0; i < 3; ++i){
                std::cout << "Value of l : " << l << std::endl ;
                std::cout << "value of i: " <<  i  << std::endl ;
                double x = xdist(mt);
                auto started_gsl = std::chrono::high_resolution_clock::now();
                gsl_sf_legendre_array_e(norm, l, x, -1, &(result_array[0]));
                auto done_gsl = std::chrono::high_resolution_clock::now(); 
                std::cout << "value of x: " << x << std::endl ;
                   for (int m = -l; m <= l; ++m){
                       std::cout << "Value of m: " << m << std::endl ;
                       //tg4 start
                       auto started_g4 = std::chrono::high_resolution_clock::now();
                       double alpg4 = lp.EvalAssocLegendrePoly(l, m, x); 
                       auto done_g4 = std::chrono::high_resolution_clock::now(); 
                       std::cout << "from alp g4:" << lp.EvalAssocLegendrePoly(l, m, x) << std::endl;
                       std::cout << "time for g4:" << std::chrono::duration_cast<std::chrono::nanoseconds>(done_g4-started_g4).count() << " nanoseconds"<< std::endl;
                       double gsl = result_array[gsl_sf_legendre_array_index(l, m)] ;
                       std::cout << "from gsl:" << result_array[gsl_sf_legendre_array_index(l, m)] << std::endl;
                       std::cout << "time for gsl:" << std::chrono::duration_cast<std::chrono::nanoseconds>(done_gsl-started_gsl).count() << " nanoseconds"<< std::endl;
                       
                      
               }
           }
       }
    }
}
// Out:
// Value of l : 0
// value of i: 0
// value of x: -0.347209
// Value of m: 0
// from alp g4:1
// time for g4:68748 nanoseconds
// from gsl:1
// time for gsl:5886 nanoseconds
// Value of l : 0
// value of i: 1
// value of x: -0.105203
// Value of m: 0
// from alp g4:1
// time for g4:478 nanoseconds
// from gsl:1
// time for gsl:351 nanoseconds
// Value of l : 0
// value of i: 2
// value of x: -0.238994
// Value of m: 0
// from alp g4:1
// time for g4:387 nanoseconds
// from gsl:1
// time for gsl:298 nanoseconds
// Value of l : 1
// value of i: 0
// value of x: -0.363413
// Value of m: -1
// from alp g4:0.465814
// time for g4:5958 nanoseconds
// from gsl:1
// time for gsl:358 nanoseconds
// Value of m: 0
// from alp g4:-0.363413
// time for g4:717 nanoseconds
// from gsl:-0.363413
// time for gsl:358 nanoseconds
// Value of m: 1
// from alp g4:-0.931628
// time for g4:664 nanoseconds
// from gsl:-0.931628
// time for gsl:358 nanoseconds
// Value of l : 1
// value of i: 1
// value of x: -0.733185
// Value of m: -1
// from alp g4:0.340015
// time for g4:673 nanoseconds
// from gsl:1
// time for gsl:400 nanoseconds
// Value of m: 0
// from alp g4:-0.733185
// time for g4:530 nanoseconds
// from gsl:-0.733185
// time for gsl:400 nanoseconds
// Value of m: 1
// from alp g4:-0.68003
// time for g4:567 nanoseconds
// from gsl:-0.68003
// time for gsl:400 nanoseconds
// Value of l : 1
// value of i: 2
// value of x: -0.871216
// Value of m: -1
// from alp g4:0.24545
// time for g4:579 nanoseconds
// from gsl:1
// time for gsl:415 nanoseconds
// Value of m: 0
// from alp g4:-0.871216
// time for g4:386 nanoseconds
// from gsl:-0.871216
// time for gsl:415 nanoseconds
// Value of m: 1
// from alp g4:-0.4909
// time for g4:497 nanoseconds
// from gsl:-0.4909
// time for gsl:415 nanoseconds
// Value of l : 2
// value of i: 0
// value of x: -0.836883
// Value of m: -2
// from alp g4:0.0374534
// time for g4:761 nanoseconds
// from gsl:-0.836883
// time for gsl:768 nanoseconds
// Value of m: -1
// from alp g4:-0.229047
// time for g4:472 nanoseconds
// from gsl:-0.547382
// time for gsl:768 nanoseconds
// Value of m: 0
// from alp g4:0.550559
// time for g4:362 nanoseconds
// from gsl:0.550559
// time for gsl:768 nanoseconds
// Value of m: 1
// from alp g4:1.37428
// time for g4:305 nanoseconds
// from gsl:1.37428
// time for gsl:768 nanoseconds
// Value of m: 2
// from alp g4:0.898882
// time for g4:422 nanoseconds
// from gsl:0.898882
// time for gsl:768 nanoseconds
// Value of l : 2
// value of i: 1
// value of x: 0.533206
// Value of m: -2
// from alp g4:0.0894615
// time for g4:596 nanoseconds
// from gsl:0.533206
// time for gsl:742 nanoseconds
// Value of m: -1
// from alp g4:0.225542
// time for g4:443 nanoseconds
// from gsl:-0.845986
// time for gsl:742 nanoseconds
// Value of m: 0
// from alp g4:-0.0735377
// time for g4:338 nanoseconds
// from gsl:-0.0735377
// time for gsl:742 nanoseconds
// Value of m: 1
// from alp g4:-1.35325
// time for g4:305 nanoseconds
// from gsl:-1.35325
// time for gsl:742 nanoseconds
// Value of m: 2
// from alp g4:2.14708
// time for g4:431 nanoseconds
// from gsl:2.14708
// time for gsl:742 nanoseconds
// Value of l : 2
// value of i: 2
// value of x: -0.300339
// Value of m: -2
// from alp g4:0.113725
// time for g4:420 nanoseconds
// from gsl:-0.300339
// time for gsl:660 nanoseconds
// Value of m: -1
// from alp g4:-0.143237
// time for g4:472 nanoseconds
// from gsl:-0.953832
// time for gsl:660 nanoseconds
// Value of m: 0
// from alp g4:-0.364694
// time for g4:366 nanoseconds
// from gsl:-0.364694
// time for gsl:660 nanoseconds
// Value of m: 1
// from alp g4:0.859421
// time for g4:381 nanoseconds
// from gsl:0.859421
// time for gsl:660 nanoseconds
// Value of m: 2
// from alp g4:2.72939
// time for g4:353 nanoseconds
// from gsl:2.72939
// time for gsl:660 nanoseconds
