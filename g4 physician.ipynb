// %%
//g4+gsl
#pragma cling add_library_path("/usr/local/lib")
#pragma cling load("libgsl.dylib")
#pragma cling add_include_path("/Users/lit.work/Downloads/Geant4-10.3.3-Darwin/include/Geant4")
#pragma cling add_library_path("/Users/lit.work/Downloads/Geant4-10.3.3-Darwin/lib")
#pragma cling load("libG4processes.dylib")
#include <iostream>
#include "G4LegendrePolynomial.hh"
#include <random>
#include <cstdlib>
#include "gsl/gsl_sf_legendre.h"
#include <stdio.h> 
#include <stdlib.h> 
#include <chrono>

{
    G4LegendrePolynomial lp;
    gsl_sf_legendre_t norm = GSL_SF_LEGENDRE_NONE;
    std::random_device rd;
    std::mt19937 mt(rd());
    std::uniform_real_distribution<double> xdist(-1, 1);
    

       for (int l=0; l < 10; ++l){
           double gsl_acc_time_ns = 0;
           double g4_acc_time_ns = 0;
           double sum_diff2 = 0;
           
           std::vector<double> result_array(gsl_sf_legendre_array_n(l), 0);
           
           
           for (int i=0; i < 1000000; ++i){
                double x = xdist(mt);
                
                auto started_gsl = std::chrono::high_resolution_clock::now();
                gsl_sf_legendre_array_e(norm, l, x, -1, &(result_array[0]));
                auto done_gsl = std::chrono::high_resolution_clock::now(); 
                 
                gsl_acc_time_ns += std::chrono::duration_cast<std::chrono::nanoseconds>(done_gsl-started_gsl).count();
                
                for (int m = 0; m <= l; ++m){
                    auto started_g4 = std::chrono::high_resolution_clock::now();
                    double alpg4 = lp.EvalAssocLegendrePoly(l, m, x); 
                    auto done_g4 = std::chrono::high_resolution_clock::now(); 
                    g4_acc_time_ns += std::chrono::duration_cast<std::chrono::nanoseconds>(done_g4-started_g4).count(); 
                    
               
                    double alp_gsl = result_array[gsl_sf_legendre_array_index(l, m)] ;
                    sum_diff2 += pow(alp_gsl - alpg4, 2);
                      
               } // loop over m
           } // loop over i
            std::cout << "L = " << l << ": sum of times for gsl:" <<   gsl_acc_time_ns * 1e-9 << " seconds" << std::endl;
            std::cout << "L = " << l << ": sum of times for g4:" <<   g4_acc_time_ns * 1e-9 << " seconds" << std::endl;
            std::cout << "L = " << l << ": sum of differences squared:" <<   sum_diff2 * 1e-18 << " seconds" << std::endl;
       } // loop over l

}
// Out:
// L = 0: sum of times for gsl:0.0365306 seconds
// L = 0: sum of times for g4:0.0270008 seconds
// L = 1: sum of times for gsl:0.0495887 seconds
// L = 1: sum of times for g4:0.0736984 seconds
// L = 2: sum of times for gsl:0.0567323 seconds
// L = 2: sum of times for g4:0.112866 seconds
// L = 3: sum of times for gsl:0.0717811 seconds
// L = 3: sum of times for g4:0.152567 seconds
// L = 4: sum of times for gsl:0.0883453 seconds
// L = 4: sum of times for g4:0.227496 seconds
// L = 5: sum of times for gsl:0.100503 seconds
// L = 5: sum of times for g4:0.38944 seconds
// L = 6: sum of times for gsl:0.128734 seconds
// L = 6: sum of times for g4:0.602782 seconds
// L = 7: sum of times for gsl:0.16391 seconds
// L = 7: sum of times for g4:1.00046 seconds
// L = 8: sum of times for gsl:0.202106 seconds
// L = 8: sum of times for g4:1.55623 seconds
// L = 9: sum of times for gsl:0.264172 seconds
// L = 9: sum of times for g4:2.61084 seconds
// L = 10: sum of times for gsl:0.302746 seconds
// L = 10: sum of times for g4:3.96572 seconds
// L = 11: sum of times for gsl:0.362546 seconds
// L = 11: sum of times for g4:6.36194 seconds
// L = 12: sum of times for gsl:0.437898 seconds
// L = 12: sum of times for g4:10.4078 seconds
// L = 13: sum of times for gsl:0.578067 seconds
// L = 13: sum of times for g4:18.5721 seconds
// L = 14: sum of times for gsl:0.625418 seconds
// L = 14: sum of times for g4:28.0333 seconds
// L = 15: sum of times for gsl:0.7407 seconds
// L = 15: sum of times for g4:46.4472 seconds
// L = 16: sum of times for gsl:0.860583 seconds
// L = 16: sum of times for g4:75.7097 seconds
// L = 17: sum of times for gsl:0.977269 seconds
// L = 17: sum of times for g4:120.31 seconds
